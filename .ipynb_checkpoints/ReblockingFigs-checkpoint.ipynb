# %%
# %matplotlib inline 

import numpy as np
import math
from matplotlib import pyplot as plt

import my_graph_helpers as mgh
import my_graph as mg

# %%
reload(mgh)
reload(mg)
# Out:
# <module 'my_graph' from 'my_graph.pyc'>

# %%
def new_length(block,a):
    myG = block.copy()    
    myG.define_roads()
    myG.define_interior_parcels()

    len(myG.interior_parcels)
    print "alpha = {}".format(a)
    
    new_roads, bisect = mgh.build_all_roads(myG, barriers=False, alpha=a, quiet=True)
    return new_roads,myG

# %%
### Import data
filename = "data/epworth_before"
place = "epworth"
rezero = np.array([305680, 8022350])
original = mgh.import_and_setup(1, filename, rezero=rezero,
                                connected=True, name=place+"_S0")
# Out:
# data loaded

# %%
component = 45

block = original.connected_components()[component]
block.define_roads()
block.define_interior_parcels()

# %%
myG = block.copy()    
myG.define_roads()
myG.define_interior_parcels()
myG.plot_roads(master=block, new_road_width = 4, old_node_size=25, old_road_width = 6)
plt.savefig("base_block.pdf", format='pdf')

new_roads = mgh.build_all_roads(myG, barriers = False, alpha = 2, wholepath = True, 
                                plot_intermediate=True)

myG.plot_roads(master=block, new_road_width = 4, old_node_size=25, old_road_width = 6, 
               barriers = False)
plt.savefig("Full_Solution.pdf", format='pdf')

# %%
myG = block.copy()    
myG.define_roads()
myG.define_interior_parcels()

len(myG.interior_parcels)
# Out:
# 7

# %%
alpha = [0.5,1]
for a in alpha:
    resultsdict={}
    reps = 2
    r = 0
    while r < reps:
        nr,myG = new_length(block,a)

        if r = 0:
            myG.plot_roads(master=block, new_road_width = 4, old_node_size=25, old_road_width = 6, 
                   barriers = False)
            plt.title(r"$\alpha = {0}$, $length = {1:.1f}$".format(str(a),myG.road_length()))
            plt.savefig("Soln_alpha_"+str(a)+".pdf", format='pdf')
        r += 1
# Out:
# alpha = 0.5
# Begin with 7 Interior Parcels
# alpha = 1
# Begin with 7 Interior Parcels
# alpha = 2
# Begin with 7 Interior Parcels
# alpha = 4
# Begin with 7 Interior Parcels
# alpha = 8
# Begin with 7 Interior Parcels
# alpha = 16
# Begin with 7 Interior Parcels

# %%
print "length = {0:.2f}".format(myG.road_length())
# Out:
# length = 617.03

# %%
new_roads
# Out:
# (118.45606040495559, 0)

# %%
block.road_length() - myG.road_length()
# Out:
# -118.45606040495591

# %%
new_roads = new_length(block,0.5)
# Out:
# alpha = 0.5
# Begin with 7 Interior Parcels

# %%
new_roads
# Out:
# [0.5, 92.188152148272607, Graph (epworth_S0) with 110 nodes]
